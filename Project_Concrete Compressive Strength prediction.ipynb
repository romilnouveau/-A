# %% [markdown]
# # CONCRETE COMPRESSIVE STRENGTH PREDICTION

# %%
from IPython.display import Image
Image(r"C:\Users\shreya\Desktop\CCS.jpg",width=750,height=90)

# %% [markdown]
# Compressive strength or compression strength is the capacity of a material or structure to withstand loads tending to
# reduce size, as opposed to tensile strength, which withstands loads tending to elongate.
# Compressive strength is one of the most important engineering properties of concrete. It is a standard industrial practice
# that the concrete is classified based on grades. This grade is nothing but the Compressive Strength of the concrete cube
# or cylinder. Cube or Cylinder samples are usually tested under a compression testing machine to obtain the compressive
# strength of concrete. The test requisites differ country to country based on the design code.
#
# **The concrete compressive strength is a highly nonlinear function of age and ingredients. These ingredients include
# cement, blast furnace slag, fly ash, water, superplasticizer, coarse aggregate, and fine aggregate.**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
cc_data=pd.read_csv(r'C:\Users\shreya\Desktop\Concrete_Data.csv')

# %% [markdown]
# # Dataset Description

# %%
cc_data.head()
# Out:
#    Cement  BF Slag  Fly Ash  Water  Superplasticizer  Coarse Aggregate  \
# 0   540.0      0.0      0.0  162.0               2.5            1040.0
# 1   540.0      0.0      0.0  162.0               2.5            1055.0
# 2   332.5    142.5      0.0  228.0               0.0             932.0
# 3   332.5    142.5      0.0  228.0               0.0             932.0
# 4   198.6    132.4      0.0  192.0               0.0             978.4
#
#    Fine Aggregate  Age (day)  CCS(MPa)
# 0           676.0         28     79.99
# 1           676.0         28     61.89
# 2           594.0        270     40.27
# 3           594.0        365     41.05
# 4           825.5        360     44.30

# %%
cc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Cement            1030 non-null   float64
#  1   BF Slag           1030 non-null   float64
#  2   Fly Ash           1030 non-null   float64
#  3   Water             1030 non-null   float64
#  4   Superplasticizer  1030 non-null   float64
#  5   Coarse Aggregate  1030 non-null   float64
#  6   Fine Aggregate    1030 non-null   float64
#  7   Age (day)         1030 non-null   int64
#  8   CCS(MPa)          1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %%
cc_data.describe()
# Out:
#             Cement      BF Slag      Fly Ash        Water  Superplasticizer  \
# count  1030.000000  1030.000000  1030.000000  1030.000000       1030.000000
# mean    281.167864    73.895825    54.188350   181.567282          6.204660
# std     104.506364    86.279342    63.997004    21.354219          5.973841
# min     102.000000     0.000000     0.000000   121.800000          0.000000
# 25%     192.375000     0.000000     0.000000   164.900000          0.000000
# 50%     272.900000    22.000000     0.000000   185.000000          6.400000
# 75%     350.000000   142.950000   118.300000   192.000000         10.200000
# max     540.000000   359.400000   200.100000   247.000000         32.200000
#
#        Coarse Aggregate  Fine Aggregate    Age (day)     CCS(MPa)
# count       1030.000000     1030.000000  1030.000000  1030.000000
# mean         972.918932      773.580485    45.662136    35.817961
# std           77.753954       80.175980    63.169912    16.705742
# min          801.000000      594.000000     1.000000     2.330000
# 25%          932.000000      730.950000     7.000000    23.710000
# 50%          968.000000      779.500000    28.000000    34.445000
# 75%         1029.400000      824.000000    56.000000    46.135000
# max         1145.000000      992.600000   365.000000    82.600000

# %% [markdown]
# # Comparing the values of Input and Output variables

# %%
fig, axes = plt.subplots(figsize=(15,7))
t=sns.boxplot(data=cc_data)
t.set_xticklabels(t.get_xticklabels())
plt.title("Box Plot of Inputs & Output")
# Out:
# Text(0.5, 1.0, 'Box Plot of Inputs & Output')

# %%
fig, axes = plt.subplots(figsize=(15,15))
plt.subplot(3,3,1)
sns.distplot(cc_data['Cement'],color='coral')
plt.subplot(3,3,2)
sns.distplot(cc_data['BF Slag'],color='c')
plt.subplot(3,3,3)
sns.distplot(cc_data['Fly Ash'],color='y')
plt.subplot(3,3,4)
sns.distplot(cc_data['Water'],color='k')
plt.subplot(3,3,5)
sns.distplot(cc_data['Superplasticizer'],color='r')                
plt.subplot(3,3,6)
sns.distplot(cc_data['Coarse Aggregate'],color='b')
plt.subplot(3,3,7)
sns.distplot(cc_data['Fine Aggregate'],color='lightblue')
plt.subplot(3,3,8)
sns.distplot(cc_data['Age (day)'],color='g')

# %% [markdown]
# # Finding the correlation btw I/O Variables

# %%
ccdata_cor=cc_data.corr()
sns.heatmap(ccdata_cor,annot=True)

# %% [markdown]
# ***The amount of cement, Superplasticizer, Age(days) and BF Slag are directly proportional to CCS(MPa) i.e. they have a positive correlation***

# %% [markdown]
# ***While, Fly Ash, Water, Coarse Aggregate & Fine Aggregate have negative correlation with the strength of the material.***

# %%
sns.jointplot(x='Cement',y='CCS(MPa)',data=cc_data,kind='kde',color='c')

# %% [markdown]
# Cement(kg/m**3) α Concrete Compressive Strength(MPa)

# %%
sns.jointplot(x='Water',y='CCS(MPa)',data=cc_data,kind='kde',color='y')

# %% [markdown]
# Water(kg/m**3) α (1/Concrete Compressive Strength(MPa))

# %% [markdown]
# # Concentration of the Inputs when Output is maximum

# %%
cc_data.max()
# Out:
# Cement                540.0
# BF Slag               359.4
# Fly Ash               200.1
# Water                 247.0
# Superplasticizer       32.2
# Coarse Aggregate     1145.0
# Fine Aggregate        992.6
# Age (day)             365.0
# CCS(MPa)               82.6
# dtype: float64

# %%
cc_data[(cc_data['CCS(MPa)']==82.6)]
# Out:
#      Cement  BF Slag  Fly Ash  Water   Superplasticizer   Coarse Aggregate   \
# 181   389.9    189.0      0.0   145.9               22.0              944.7
#
#      Fine Aggregate   Age (day)  CCS(MPa)
# 181            755.8         91      82.6

# %%
cc_data[(cc_data['Cement']==540.0)]
# Out:
#      Cement  BF Slag  Fly Ash  Water  Superplasticizer  Coarse Aggregate  \
# 0     540.0      0.0      0.0  162.0               2.5            1040.0
# 1     540.0      0.0      0.0  162.0               2.5            1055.0
# 751   540.0      0.0      0.0  173.0               0.0            1125.0
# 752   540.0      0.0      0.0  173.0               0.0            1125.0
# 753   540.0      0.0      0.0  173.0               0.0            1125.0
# 754   540.0      0.0      0.0  173.0               0.0            1125.0
# 755   540.0      0.0      0.0  173.0               0.0            1125.0
# 756   540.0      0.0      0.0  173.0               0.0            1125.0
# 799   540.0      0.0      0.0  173.0               0.0            1125.0
#
#      Fine Aggregate  Age (day)  CCS(MPa)
# 0             676.0         28     79.99
# 1             676.0         28     61.89
# 751           613.0          7     52.61
# 752           613.0         14     59.76
# 753           613.0         28     67.31
# 754           613.0         90     69.66
# 755           613.0        180     71.62
# 756           613.0        270     74.17
# 799           613.0          3     41.64

# %%
max_data=np.array(cc_data.drop(['CCS(MPa)'],axis=1).iloc[181]) # since 181 column had the max.CCS(MPa)
labels=['Cement','BF Slag','Fly Ash','Water','Superplasticizer','Coarse Aggregate','Fine Aggregate','Age (day)']
explode = (0, 0, 0, 0, 0, 0.1, 0, 0)
fig1, ax1 = plt.subplots()
ax1.pie(max_data, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal') 
plt.show()

# %% [markdown]
# The pie chart of the input variables concentration that give the max CCS(MPa).

# %%
cc_data['CCS(MPa)'].plot.hist(bins=200)
plt.xlabel('Concrete compressive stength')
# Out:
# Text(0.5, 0, 'Concrete compressive stength')

# %% [markdown]
# **Normal distribution curve shows that a majority of CCS(MPa) for different input variables is concentrated around 40MPa.**
